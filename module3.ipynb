# %% [markdown]
# <a href="https://colab.research.google.com/github/kvssri/aiml2026_labs_projects/blob/main/module3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from scipy.ndimage import rotate, affine_transform

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_X = train_X / 255.0
test_X = test_X / 255.0

# %%
def NN1(train_X, train_y, test_X):
    predictions = []
    for test_img in test_X:
        distances = np.sum((train_X - test_img)**2, axis=(1,2))
        nearest_index = np.argmin(distances)
        predictions.append(train_y[nearest_index])
    return np.array(predictions)

# %%
testpred = NN1(train_X, train_y, test_X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_454/134272679.py in <cell line: 0>()
# ----> 1 testpred = NN1(train_X, train_y, test_X)
#
# /tmp/ipykernel_454/2615106155.py in NN1(train_X, train_y, test_X)
#       2     predictions = []
#       3     for test_img in test_X:
# ----> 4         distances = np.sum((train_X - test_img)**2, axis=(1,2))
#       5         nearest_index = np.argmin(distances)
#       6         predictions.append(train_y[nearest_index])
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2248
#    2249
# -> 2250 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2251                     initial=None, where=None):
#    2252     return (a, out)
#
# KeyboardInterrupt:

# %%
testpred = NN(train_X, train_y, test_X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_454/527495195.py in <cell line: 0>()
# ----> 1 testpred = NN(train_X, train_y, test_X)
#
# NameError: name 'NN' is not defined

# %%
testpred = NN1(train_X, train_y, test_X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_454/134272679.py in <cell line: 0>()
# ----> 1 testpred = NN1(train_X, train_y, test_X)
#
# /tmp/ipykernel_454/2615106155.py in NN1(train_X, train_y, test_X)
#       2     predictions = []
#       3     for test_img in test_X:
# ----> 4         distances = np.sum((train_X - test_img)**2, axis=(1,2))
#       5         nearest_index = np.argmin(distances)
#       6         predictions.append(train_y[nearest_index])
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2248
#    2249
# -> 2250 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2251                     initial=None, where=None):
#    2252     return (a, out)
#
# KeyboardInterrupt:

# %%
train_X_small = train_X[:2000]
train_y_small = train_y[:2000]

test_X_small = test_X[:200]
test_y_small = test_y[:200]

# %%
testpred = NN1(train_X_small, train_y_small, test_X_small)
accuracy = np.mean(testpred == test_y_small)
print("Baseline Accuracy:", accuracy)
# Out:
# Baseline Accuracy: 0.875

# %%
aug_train_X_small = aug_train_X[:2000]
aug_train_y_small = aug_train_y[:2000]

aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)
aug_accuracy = np.mean(aug_pred == test_y_small)

print("Augmented Accuracy:", aug_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_454/4064933696.py in <cell line: 0>()
# ----> 1 aug_train_X_small = aug_train_X[:2000]
#       2 aug_train_y_small = aug_train_y[:2000]
#       3
#       4 aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)
#       5 aug_accuracy = np.mean(aug_pred == test_y_small)
#
# NameError: name 'aug_train_X' is not defined

# %%
train_X_small = train_X[:1000]
test_X_small = test_X[:100]

# %%
aug_train_X_small = aug_train_X[:2000]
aug_train_y_small = aug_train_y[:2000]

aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)
aug_accuracy = np.mean(aug_pred == test_y_small)

print("Augmented Accuracy:", aug_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_454/4064933696.py in <cell line: 0>()
# ----> 1 aug_train_X_small = aug_train_X[:2000]
#       2 aug_train_y_small = aug_train_y[:2000]
#       3
#       4 aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)
#       5 aug_accuracy = np.mean(aug_pred == test_y_small)
#
# NameError: name 'aug_train_X' is not defined

# %%
from scipy.ndimage import rotate, affine_transform

# Rotation
rotated_images = np.array([rotate(img, angle=15, reshape=False) for img in train_X])

# Affine Transformation
affine_images = np.array([
    affine_transform(img, matrix=[[1,0.2],[0.1,1]], offset=0)
    for img in train_X
])

# %%
aug_train_X = np.concatenate((train_X, rotated_images, affine_images))
aug_train_y = np.concatenate((train_y, train_y, train_y))

# %%
aug_train_X_small = aug_train_X[:2000]
aug_train_y_small = aug_train_y[:2000]

# %%
aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)

# %%
aug_accuracy = np.mean(aug_pred == test_y_small)
print("Augmented Accuracy:", aug_accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_454/1690030181.py in <cell line: 0>()
# ----> 1 aug_accuracy = np.mean(aug_pred == test_y_small)
#       2 print("Augmented Accuracy:", aug_accuracy)
#
# ValueError: operands could not be broadcast together with shapes (100,) (200,)

# %%
test_X_small = test_X[:200]
test_y_small = test_y[:200]

# %%
test_X_small = test_X[:100]
test_y_small = test_y[:100]

# %%
aug_pred = NN1(aug_train_X_small, aug_train_y_small, test_X_small)

aug_accuracy = np.mean(aug_pred == test_y_small)
print("Augmented Accuracy:", aug_accuracy)
# Out:
# Augmented Accuracy: 0.86

# %%
plt.imshow(train_X[0], cmap='gray')
plt.title("Original Image")
plt.show()

plt.imshow(rotated_images[0], cmap='gray')
plt.title("Rotated Image")
plt.show()
